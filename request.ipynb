# %%
from yahoo_finance import Share

# %%
import yfinance as yf

# %%
twtr=yf.Ticker('TWTR')

# %%
twtr.info
# Out:
# {'zip': '94103',
#  'sector': 'Communication Services',
#  'fullTimeEmployees': 5200,
# ...

# %%
df  =  twtr.history(start="2010-01-01",  end="2020-08-31")

# %%
data = json.dumps([close[0], volume[0]])
data
# Out:
# '[44.9, 117701600]'

# %%
df
# Out:
#              Open   High    Low  Close     Volume  Dividends  Stock Splits
# Date
# 2013-11-07  45.10  50.09  44.00  44.90  117701600          0             0
# 2013-11-08  45.93  46.94  40.69  41.65   27925300          0             0
# 2013-11-11  40.50  43.00  39.40  42.90   16113900          0             0
# 2013-11-12  43.66  43.78  41.83  41.90    6316700          0             0
# 2013-11-13  41.03  42.87  40.76  42.60    8688300          0             0
# ...           ...    ...    ...    ...        ...        ...           ...
# 2020-08-24  39.68  40.80  39.64  40.49   20496600          0             0
# 2020-08-25  40.44  40.70  39.32  40.55   12470500          0             0
# 2020-08-26  40.55  41.33  40.00  41.08   12532500          0             0
# 2020-08-27  40.97  41.25  40.07  40.39   13055000          0             0
# 2020-08-28  40.50  41.17  40.42  41.07    8024400          0             0
#
# [1714 rows x 7 columns]

# %%
close = df['Close'].tolist()
volume = df['Volume'].tolist()

# %%
balance=93.51999599999999

# %%
requests.get('http://localhost:8005/trade?data='+data).json()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ...
